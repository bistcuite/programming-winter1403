# %% [markdown]
# # `np.arange` و `np.linspace`

# %%
import numpy as np

# %%
a = np.arange(3)
a
# Out:
# array([0, 1, 2])

# %%
b = np.arange(3,7)
b
# Out:
# array([3, 4, 5, 6])

# %%
c = np.arange(3,7,2)
c
# Out:
# array([3, 5])

# %% [markdown]
# ## چرا؟
# چون نام‌پای سرعت بالاتری دارد، همچنین می‌توان از اعداد اعشاری استفاده کرد.

# %%
a1 = np.linspace(2.0, 3.0, num=5)
a1
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %%
d = np.linspace(2.0,3.0, num=5)
d
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %% [markdown]
# # مسئله اول

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 500)

# %%
y =  0.5 * np.cos(2 * x) + np.sin(x)

# %%
plt.plot(x, y)
plt.title('f(x) = 0.5 cos(2x) + sin(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)

# %% [markdown]
# # مسئله دوم

# %%
def f(x):
  return  0.5 * np.cos(2 * x) + np.sin(x)

# %%
a = 0 # کران پایین
b = 3 # کران بالا
n = 1000000 # تعداد مستطیل ها
total = 0

dx = (b - a) / n

# %%
for i in range(n):
  x = a + i * dx
  total += f(x) * dx

total
# Out:
# 1.9201384402416952
